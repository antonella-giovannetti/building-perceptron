# %% [markdown]
# # Analyse exploratoire des données Breast Cancer Wisconsin

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
file_path = './data/bcw_data.csv'
data = pd.read_csv(file_path)

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# Suppression des colonnes inutiles

# %%
if 'Unnamed: 32' in data.columns:
    data.drop(columns=['Unnamed: 32'], inplace=True)
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# Doublons

# %%
duplicates = data.duplicated()
print(f"Nombre de doublons : {duplicates.sum()}")
# Out:
# Nombre de doublons : 0

# %% [markdown]
# Valeurs manquantes

# %%
missing_values = data.isnull().sum()
print("Valeurs manquantes par colonne :")
print(missing_values[missing_values > 0])
# Out:
# Valeurs manquantes par colonne :
# Series([], dtype: int64)

# %% [markdown]
# Analyse des valeurs aberrantes

# %% [markdown]
# Statistiques descriptives :

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# Répartition de la variable cible

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='diagnosis', data=data, palette='pastel')
plt.title('Répartition des diagnostics (M = Malignant, B = Benign)')
plt.show()
# Out:
# C:\Users\anton\AppData\Local\Temp\ipykernel_7108\1719719464.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='diagnosis', data=data, palette='pastel')

# %% [markdown]
# Visualisations des distributions des variables numériques

# %%
num_cols = data.select_dtypes(include=['float64']).columns
plt.figure(figsize=(15, 10))
data[num_cols].hist(bins=15, figsize=(20, 15), layout=(5, 6), color='teal', edgecolor='black')
plt.suptitle('Distribution des variables numériques')
plt.show()

# %% [markdown]
# Analyse de la matrice de corrélation

# %%
plt.figure(figsize=(12, 10))
corr_matrix = data[num_cols].corr()
sns.heatmap(corr_matrix, cmap='coolwarm', annot=False)
plt.title('Matrice de corrélation')
plt.show()

# %%
data['diagnosis'] = data['diagnosis'].map({'M': 1, 'B': 0})  # Encoder 'diagnosis' (M = 1, B = 0)

# Séparer les caractéristiques et la cible
X = data.drop(columns=['diagnosis'])
y = data['diagnosis']

# Normalisation des données
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Application de l'ACP pour réduire à 2 composantes
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Création d'un DataFrame pour la visualisation
pca_df = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
pca_df['Diagnosis'] = y.map({1: 'Malignant', 0: 'Benign'})

# Visualisation en 2D
plt.figure(figsize=(10, 7))
sns.scatterplot(data=pca_df, x='PC1', y='PC2', hue='Diagnosis', palette='coolwarm', alpha=0.7)
plt.title('Visualisation des données avec l\'ACP (2 composantes principales)')
plt.xlabel('Composante Principale 1')
plt.ylabel('Composante Principale 2')
plt.legend(title='Diagnostic')
plt.grid(True)
plt.show()
